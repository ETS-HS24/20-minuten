# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
directory_path = '../data/processed'

# %% [markdown]
# # Topic matching by translation using LSA

# %%
df = pd.read_csv(f'{directory_path}/lsa_matches_by_translation.csv')
df.drop('Unnamed: 0', axis='columns', inplace=True)
# df = df.drop_duplicates()
df_german = df['german'].value_counts()
df_french = df['french'].value_counts()
print(df_german)
print(df_french)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 5))
df_german.plot(title="Topic matching by translation using LSA - German", legend=True, ax=ax1, kind='bar')
df_french.plot(title="Topic matching by translation using LSA - French", legend=True, ax=ax2, kind='bar',
               color='orange')
plt.tight_layout()
# Out:
# polizei      9
# kind         7
# maske        7
# schweizer    6
# mensch       4
# museum       4
# mann         3
# trump        3
# frau         3
# china        2
# stadt        2
# projekt      2
# club         1
# virtuell     1
# firma        1
# virus        1
# million      1
# Name: german, dtype: int64
# police        9
# enfant        7
# masque        7
# suisse        6
# humain        4
# musée         4
# homme         3
# trump         3
# femme         3
# chine         2
# ville         2
# projet        2
# club          1
# virtuel       1
# entreprise    1
# virus         1
# million       1
# Name: french, dtype: int64

# %% [markdown]
# # Topic matching by translation using LDA

# %%
df = pd.read_csv(f'{directory_path}/lda_matches_by_translation.csv')
df.drop('Unnamed: 0', axis='columns', inplace=True)
# df = df.drop_duplicates()
df_german = df['german'].value_counts()
df_french = df['french'].value_counts()
print(df_german)
print(df_french)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 5))
df_german.plot(title="Topic matching by translation using LDA - German", legend=True, ax=ax1, kind='bar')
df_french.plot(title="Topic matching by translation using LDA - French", legend=True, ax=ax2, kind='bar',
               color='orange')
plt.tight_layout()
# Out:
# polizei      10
# kind          7
# minute        4
# schweizer     4
# woche         3
# frau          2
# museum        2
# million       2
# monat         2
# trump         2
# apple         1
# mann          1
# meghan        1
# projekt       1
# facebook      1
# Name: german, dtype: int64
# police      10
# enfant       7
# minute       4
# suisse       4
# semaine      3
# femme        2
# musée        2
# million      2
# mois         2
# trump        2
# apple        1
# homme        1
# meghan       1
# projet       1
# facebook     1
# Name: french, dtype: int64

# %% [markdown]
# # Topic matching by sentence transformer using LSA ann match_score=0.9

# %%
df = pd.read_csv(f'{directory_path}/best_lsa_matches_by_sentence_transformer.csv')
df.drop('Unnamed: 0', axis='columns', inplace=True)
# df = df.drop_duplicates()
df_german = df['german'].value_counts()
df_french = df['french'].value_counts()
print(df_german)
print(df_french)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 5))
df_german.plot(title="Topic matching by sentence transformer using LSA and match_score=0.9 - German", legend=True, ax=ax1, kind='bar')
df_french.plot(title="Topic matching by sentence transformer using LSA and match_score=0.9 - French", legend=True, ax=ax2, kind='bar', color='orange')
plt.tight_layout()
# Out:
# polizei        15
# schweizer      13
# schweiz         5
# swiss           4
# auto            4
# the             2
# projekt         2
# million         1
# coronavirus     1
# Name: german, dtype: int64
# suisse         22
# police         15
# voiture         4
# the             2
# projet          2
# million         1
# coronavirus     1
# Name: french, dtype: int64

# %% [markdown]
# # Topic matching by sentence transformer using LDA and match_score=0.9

# %%
df = pd.read_csv(f'{directory_path}/best_lda_matches_by_sentence_transformer.csv')
df.drop('Unnamed: 0', axis='columns', inplace=True)
# df = df.drop_duplicates()
df_german = df['german'].value_counts()
df_french = df['french'].value_counts()
print(df_german)
print(df_french)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 5))
df_german.plot(title="Topic matching by sentence transformer using LDA and match_score=0.9 - German", legend=True, ax=ax1, kind='bar')
df_french.plot(title="Topic matching by sentence transformer using LDA and match_score=0.9 - French", legend=True, ax=ax2, kind='bar', color='orange')
plt.tight_layout()
# Out:
# schweiz        16
# polizei        16
# swiss          16
# schweizer       4
# coronavirus     4
# the             3
# million         2
# berset          1
# auto            1
# meghan          1
# Name: german, dtype: int64
# suisse         36
# police         15
# coronavirus     4
# the             3
# million         2
# mettre          1
# voiture         1
# policier        1
# falloir         1
# Name: french, dtype: int64
